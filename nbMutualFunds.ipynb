# %%
import textwrap
from api_Finance.db_interface import CDBInterface
from api_Finance.performance_analyzer import CPerformanceAnalyzer

objConsole = CDBInterface()
objAnalyzer = CPerformanceAnalyzer()

# Fetch current NAVs
objConsole.FetchNAVsAll(bForceUpdate=False)
# Out:
# Loaded 37656 schemes from local cache (date=2026-07-07).

# %% [markdown]
# ---
# # <font color='red'>Analysis</font>

# %% [markdown]
# ## <font color='blue'> Update today's NAVs</font>

# %%
objConsole.UpdateAllFundNAVs()
objAnalyzer.RecordTodayHistory()      # snapshot today's NAVs
# Out:
# #0. No change for ADITYA BIRLA SUN LIFE SILVER ETF FOF REGULAR-GROWTH: NAV=35.0888 — skipping update
# #1. No change for HDFC SILVER ETF FOF REGULAR - GROWTH: NAV=37.5687 — skipping update
# #2. No change for HSBC INFRASTRUCTURE FUND-GROWTH: NAV=27.8862 — skipping update
# #3. No change for ICICI PRUDENTIAL LARGE & MID CAP FUND-GROWTH: NAV=1033.19 — skipping update
# #4. No change for ICICI PRUDENTIAL SILVER ETF FOF - GROWTH: NAV=34.5335 — skipping update
# #5. No change for LIC MF CONSUMPTION FUND REGULAR-GROWTH: NAV=9.8188 — skipping update
# #6. No change for NIPPON INDIA LARGE CAP FUND-GROWTH: NAV=90.8392 — skipping update
# #7. No change for NIPPON INDIA SILVER ETF FOF REGULAR - GROWTH: NAV=34.5438 — skipping update
# #8. No change for SBI GOLD FUND-GROWTH: NAV=42.1141 — skipping update
# #9. No change for SBI SILVER ETF FOF REGULAR-GROWTH: NAV=24.4249 — skipping update
# #10. No change for TATA SILVER ETF FOF REGULAR - GROWTH: NAV=29.849 — skipping update
#
# Updated NAV for 0/11 entries (11 unchanged, 0 new highs, 0 new lows).
# Recorded NAV history for 11 distinct fund(s) on 2026-07-07.

# %% [markdown]
# ## Summary

# %%
objConsole.FundsSummaryV2('SG')
# Out:
# __________________________________________________________________________________________________________
#
# Fund House & Scheme Name            Units   NAV Base NAV Latest NAV Change      Cost Value  Expected Value
# __________________________________________________________________________________________________________
# ADITYA BIRLA SUN LIFE SILVER     2851.131    35.0738    35.0888        N/A      100,000.00      100,042.77
# ETF FOF REGULAR-GROWTH
# HDFC SILVER ETF FOF REGULAR -    2659.313    37.6037    37.5687        N/A      100,000.00       99,906.92
# GROWTH
# HSBC INFRASTRUCTURE FUND-        3586.003    27.8862    27.8862        N/A      100,000.00      100,000.00
# GROWTH
# ICICI PRUDENTIAL LARGE & MID      104.941   952.9200  1033.1900        N/A      100,000.00      108,423.58
# CAP FUND-GROWTH
# ICICI PRUDENTIAL SILVER ETF      2893.066    34.5654    34.5335        N/A      100,000.00       99,907.71
# FOF - GROWTH
# LIC MF CONSUMPTION FUND         11389.522     8.7800     9.8188        N/A      100,000.00      111,831.44
# REGULAR-GROWTH
# NIPPON INDIA LARGE CAP FUND-     1184.234    84.4428    90.8392        N/A      100,000.00      107,574.83
# GROWTH
# NIPPON INDIA SILVER ETF FOF      2895.420    34.5373    34.5438        N/A      100,000.00      100,018.82
# REGULAR - GROWTH
# SBI GOLD FUND-GROWTH             2328.576    42.9447    42.1141        N/A      100,000.00       98,065.88
# SBI SILVER ETF FOF REGULAR-      4097.219    24.4068    24.4249        N/A      100,000.00      100,074.16
# GROWTH
# TATA SILVER ETF FOF REGULAR -    3343.598    29.9079    29.8490        N/A      100,000.00       99,803.06
# GROWTH
# __________________________________________________________________________________________________________
# TOTAL                                                                         1,100,000.00    1,125,649.18
# __________________________________________________________________________________________________________
#
# Total entries in DB: 11

# %%
objConsole.OwnerProfitSummary('SG')
# Out:
# Owner: SG | Funds: 11
# _________________________________________________________________________________________________________________
#
# Fund House & Scheme Name            Units   Base NAV Latest NAV          P/L Highest NAV Projected P/L Lowest NAV
# _________________________________________________________________________________________________________________
# ADITYA BIRLA SUN LIFE SILVER     2851.131    35.0738    35.0888        42.77    56.2622    60,410.91     8.6552
# ETF FOF REGULAR-GROWTH
# HDFC SILVER ETF FOF REGULAR -    2659.313    37.6037    37.5687       -93.08    60.6649    61,326.94     9.9400
# GROWTH
# HSBC INFRASTRUCTURE FUND-        3586.003    27.8862    27.8862         0.00    28.8644     3,507.83     7.2629
# GROWTH
# ICICI PRUDENTIAL LARGE & MID      104.941   952.9200  1033.1900     8,423.58  1063.3700    11,590.69    60.7900
# CAP FUND-GROWTH
# ICICI PRUDENTIAL SILVER ETF      2893.066    34.5654    34.5335       -92.29    55.3406    60,104.03     8.5103
# FOF - GROWTH
# LIC MF CONSUMPTION FUND         11389.522     8.7800     9.8188    11,831.44    10.0192    14,113.90     8.4913
# REGULAR-GROWTH
# NIPPON INDIA LARGE CAP FUND-     1184.234    84.4428    90.8392     7,574.83    94.7726    12,232.90     5.8761
# GROWTH
# NIPPON INDIA SILVER ETF FOF      2895.420    34.5373    34.5438        18.82    55.5767    60,917.91     8.4564
# REGULAR - GROWTH
# SBI GOLD FUND-GROWTH             2328.576    42.9447    42.1141    -1,934.12    51.6546    20,281.66     8.2281
# SBI SILVER ETF FOF REGULAR-      4097.219    24.4068    24.4249        74.16    38.6835    58,494.76     8.6654
# GROWTH
# TATA SILVER ETF FOF REGULAR -    3343.598    29.9079    29.8490      -196.94    46.3427    54,951.37     9.6589
# GROWTH
# _________________________________________________________________________________________________________________
# TOTAL                                                              25,649.18              417,932.89
# _________________________________________________________________________________________________________________

# %% [markdown]
# ## <font color='blue'>Performance</font>

# %%
listFunds = objConsole.UniqueFundNames()
for fund_name in listFunds:
    objAnalyzer.PlotFundNAV(fund_name)

# %%
objAnalyzer.PerformanceSummary('SG')  # print indicators

# %% [markdown]
# ---
# # <font color='red'>Update entrics</font>

# %% [markdown]
# ## Fund list

# %% [markdown]
# ### By fund name

# %%
listFunds = objConsole.Funds_by_name('HSBC INFRASTRUCTURE FUND-REGULAR GROWTH')
#objConsole.Funds_by_name('GROWTH')

# %% [markdown]
# ## Fetch Current NAV

# %%
for strFund in listFunds:
    #print(type(fund), listFunds[0])
    print(strFund, objConsole.GetFundNAV(strFund))

# %% [markdown]
# ## <font color='blue'>Fetch and Update Lowest and Highest NAV</font>

# %%
listFunds = objConsole.UniqueFundNames()
print(len(listFunds), textwrap.fill(str(listFunds), 80))
# Out:
# 11 ['ADITYA BIRLA SUN LIFE SILVER ETF FOF REGULAR-GROWTH', 'HDFC SILVER ETF FOF
# REGULAR - GROWTH', 'HSBC INFRASTRUCTURE FUND-GROWTH', 'ICICI PRUDENTIAL LARGE &
# MID CAP FUND-GROWTH', 'ICICI PRUDENTIAL SILVER ETF FOF - GROWTH', 'LIC MF
# CONSUMPTION FUND REGULAR-GROWTH', 'NIPPON INDIA LARGE CAP FUND-GROWTH', 'NIPPON
# INDIA SILVER ETF FOF REGULAR - GROWTH', 'SBI GOLD FUND-GROWTH', 'SBI SILVER ETF
# FOF REGULAR-GROWTH', 'TATA SILVER ETF FOF REGULAR - GROWTH']

# %%
for nI, fund_name in enumerate(listFunds):
    dictNAV_Data = objConsole.GetFundHigestNAV(fund_name)
    #print(textwrap.fill(str(dictNAV_Data), width=80))
    nav_highest = dictNAV_Data['nav_highest']
    print('#', nI, nav_highest)
    objConsole.ReviseHighestNav(fund_name, nav_highest)

print('DONE')
# Out:
# # 0 56.2622
# nav_highest set for ADITYA BIRLA SUN LIFE SILVER ETF FOF REGULAR-GROWTH (owner=SG): 56.2622
#
# Updated 1 row(s) for ADITYA BIRLA SUN LIFE SILVER ETF FOF REGULAR-GROWTH.
# # 1 60.6649
# nav_highest set for HDFC SILVER ETF FOF REGULAR - GROWTH (owner=SG): 60.6649
#
# Updated 1 row(s) for HDFC SILVER ETF FOF REGULAR - GROWTH.
# # 2 28.8644
# nav_highest set for HSBC INFRASTRUCTURE FUND-GROWTH (owner=SG): 28.8644
#
# Updated 1 row(s) for HSBC INFRASTRUCTURE FUND-GROWTH.
# # 3 1063.37
# nav_highest set for ICICI PRUDENTIAL LARGE & MID CAP FUND-GROWTH (owner=SG): 1063.37
#
# Updated 1 row(s) for ICICI PRUDENTIAL LARGE & MID CAP FUND-GROWTH.
# # 4 55.3406
# nav_highest set for ICICI PRUDENTIAL SILVER ETF FOF - GROWTH (owner=SG): 55.3406
#
# Updated 1 row(s) for ICICI PRUDENTIAL SILVER ETF FOF - GROWTH.
# # 5 10.0192
# nav_highest set for LIC MF CONSUMPTION FUND REGULAR-GROWTH (owner=SG): 10.0192
#
# Updated 1 row(s) for LIC MF CONSUMPTION FUND REGULAR-GROWTH.
# # 6 94.7726
# nav_highest set for NIPPON INDIA LARGE CAP FUND-GROWTH (owner=SG): 94.7726
#
# Updated 1 row(s) for NIPPON INDIA LARGE CAP FUND-GROWTH.
# # 7 55.5767
# nav_highest set for NIPPON INDIA SILVER ETF FOF REGULAR - GROWTH (owner=SG): 55.5767
#
# Updated 1 row(s) for NIPPON INDIA SILVER ETF FOF REGULAR - GROWTH.
# # 8 51.6546
# nav_highest set for SBI GOLD FUND-GROWTH (owner=SG): 51.6546
#
# Updated 1 row(s) for SBI GOLD FUND-GROWTH.
# # 9 38.6835
# nav_highest set for SBI SILVER ETF FOF REGULAR-GROWTH (owner=SG): 38.6835
#
# Updated 1 row(s) for SBI SILVER ETF FOF REGULAR-GROWTH.
# # 10 46.3427
# nav_highest set for TATA SILVER ETF FOF REGULAR - GROWTH (owner=SG): 46.3427
#
# Updated 1 row(s) for TATA SILVER ETF FOF REGULAR - GROWTH.
# DONE

# %%
for nI, fund_name in enumerate(listFunds):
    dictNAV_Data = objConsole.GetFundLowestNAV(fund_name)
    #print(textwrap.fill(str(dictNAV_Data), width=80))
    nav_lowest = dictNAV_Data['nav_lowest']
    print('#', nI, nav_lowest)
    objConsole.ReviseLowestNav(fund_name, nav_lowest)

print('DONE')
# Out:
# # 0 8.6552
# nav_lowest set for ADITYA BIRLA SUN LIFE SILVER ETF FOF REGULAR-GROWTH (owner=SG): 8.6552
#
# Updated 1 row(s) for ADITYA BIRLA SUN LIFE SILVER ETF FOF REGULAR-GROWTH.
# # 1 9.94
# nav_lowest set for HDFC SILVER ETF FOF REGULAR - GROWTH (owner=SG): 9.94
#
# Updated 1 row(s) for HDFC SILVER ETF FOF REGULAR - GROWTH.
# # 2 7.2629
# nav_lowest set for HSBC INFRASTRUCTURE FUND-GROWTH (owner=SG): 7.2629
#
# Updated 1 row(s) for HSBC INFRASTRUCTURE FUND-GROWTH.
# # 3 60.79
# nav_lowest set for ICICI PRUDENTIAL LARGE & MID CAP FUND-GROWTH (owner=SG): 60.79
#
# Updated 1 row(s) for ICICI PRUDENTIAL LARGE & MID CAP FUND-GROWTH.
# # 4 8.5103
# nav_lowest set for ICICI PRUDENTIAL SILVER ETF FOF - GROWTH (owner=SG): 8.5103
#
# Updated 1 row(s) for ICICI PRUDENTIAL SILVER ETF FOF - GROWTH.
# # 5 8.4913
# nav_lowest set for LIC MF CONSUMPTION FUND REGULAR-GROWTH (owner=SG): 8.4913
#
# Updated 1 row(s) for LIC MF CONSUMPTION FUND REGULAR-GROWTH.
# # 6 5.8761
# nav_lowest set for NIPPON INDIA LARGE CAP FUND-GROWTH (owner=SG): 5.8761
#
# Updated 1 row(s) for NIPPON INDIA LARGE CAP FUND-GROWTH.
# # 7 8.4564
# nav_lowest set for NIPPON INDIA SILVER ETF FOF REGULAR - GROWTH (owner=SG): 8.4564
#
# Updated 1 row(s) for NIPPON INDIA SILVER ETF FOF REGULAR - GROWTH.
# # 8 8.2281
# nav_lowest set for SBI GOLD FUND-GROWTH (owner=SG): 8.2281
#
# Updated 1 row(s) for SBI GOLD FUND-GROWTH.
# # 9 8.6654
# nav_lowest set for SBI SILVER ETF FOF REGULAR-GROWTH (owner=SG): 8.6654
#
# Updated 1 row(s) for SBI SILVER ETF FOF REGULAR-GROWTH.
# # 10 9.6589
# nav_lowest set for TATA SILVER ETF FOF REGULAR - GROWTH (owner=SG): 9.6589
#
# Updated 1 row(s) for TATA SILVER ETF FOF REGULAR - GROWTH.
# DONE

# %% [markdown]
# # Populate database

# %%
from api_Finance.seed_historical_holdings import CDatabaseBuilder
from config_db import LIST_FUNDS

objDatabaseBuilder = CDatabaseBuilder()
objDatabaseBuilder.seed_historical_holdings(owner_name="SG",
                         listFunds=LIST_FUNDS, months_back=3)
# Out:
# DatabaseBuilder
# Downloading full scheme list from mfapi.in (one-time)...
# Loaded 37656 schemes and cached to scheme_cache.json.
#
# Seeding purchases as of 2026-04-07 (3 month(s) before 2026-07-07).
#
# --- ADITYA BIRLA SUN LIFE SILVER ETF FOF REGULAR-GROWTH ---
# Inserted holding: units=2851.131, nav_base=35.0738 (2026-04-07), cost_value=100,000.00
# Backfilled 61 nav_history row(s) from 2026-04-07 to 2026-07-06.
#
# --- HDFC SILVER ETF FOF REGULAR - GROWTH ---
# Inserted holding: units=2659.313, nav_base=37.6037 (2026-04-07), cost_value=100,000.00
# Backfilled 61 nav_history row(s) from 2026-04-07 to 2026-07-06.
#
# --- HSBC INFRASTRUCTURE FUND-GROWTH ---
# Inserted holding: units=3586.003, nav_base=27.8862 (2022-11-25), cost_value=100,000.00
# Backfilled 1 nav_history row(s) from 2022-11-25 to 2022-11-25.
#
# --- ICICI PRUDENTIAL LARGE & MID CAP FUND-GROWTH ---
# Inserted holding: units=104.941, nav_base=952.9200 (2026-04-07), cost_value=100,000.00
# Backfilled 61 nav_history row(s) from 2026-04-07 to 2026-07-06.
#
# --- ICICI PRUDENTIAL SILVER ETF FOF - GROWTH ---
# Inserted holding: units=2893.066, nav_base=34.5654 (2026-04-07), cost_value=100,000.00
# Backfilled 61 nav_history row(s) from 2026-04-07 to 2026-07-06.
#
# --- LIC MF CONSUMPTION FUND REGULAR-GROWTH ---
# Inserted holding: units=11389.522, nav_base=8.7800 (2026-04-07), cost_value=100,000.00
# Backfilled 61 nav_history row(s) from 2026-04-07 to 2026-07-06.
#
# --- NIPPON INDIA LARGE CAP FUND-GROWTH ---
# Inserted holding: units=1184.234, nav_base=84.4428 (2026-04-07), cost_value=100,000.00
# Backfilled 61 nav_history row(s) from 2026-04-07 to 2026-07-06.
#
# --- NIPPON INDIA SILVER ETF FOF REGULAR - GROWTH ---
# Inserted holding: units=2895.420, nav_base=34.5373 (2026-04-07), cost_value=100,000.00
# Backfilled 61 nav_history row(s) from 2026-04-07 to 2026-07-06.
#
# --- SBI GOLD FUND-GROWTH ---
# Inserted holding: units=2328.576, nav_base=42.9447 (2026-04-07), cost_value=100,000.00
# Backfilled 62 nav_history row(s) from 2026-04-07 to 2026-07-06.
#
# --- SBI SILVER ETF FOF REGULAR-GROWTH ---
# Inserted holding: units=4097.219, nav_base=24.4068 (2026-04-07), cost_value=100,000.00
# Backfilled 62 nav_history row(s) from 2026-04-07 to 2026-07-06.
#
# --- TATA SILVER ETF FOF REGULAR - GROWTH ---
# Inserted holding: units=3343.598, nav_base=29.9079 (2026-04-07), cost_value=100,000.00
# Backfilled 61 nav_history row(s) from 2026-04-07 to 2026-07-06.
#
# Done.
