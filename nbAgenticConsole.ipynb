# %%
from rich.console import Console
from rich.panel import Panel
from rich.text import Text

from agentic_console import build_orchestrator
from config_agent import print_wrap

def print_rich_reflection(data: dict):
    console = Console()
    console.print(Panel.fit(
            Text(data.get('summary', ''), style="cyan"),
            title=f"🤖 Agent Reflection — {'✅ SUCCESS' if data.get('success') else '❌ FAILED'} "
                f"({data.get('steps_ok')}/{data.get('steps_total')} steps)",
            border_style="green" if data.get('success') else "red"
        )
    )

objOrchestrator = build_orchestrator(allow_writes=True)
# Out:
# Initialize Ollama server
# Ollama is already running.
# Ollama client initialized.
# Cache is stale (cached=2026-07-13, today=2026-07-27) - refreshing.
# Downloading full scheme list from mfapi.in (one-time)...
# Loaded 37693 schemes and cached to scheme_cache.json.

# %% [markdown]
# # Example 1

# %%
# Example goals — the TPA plans, the TSA fills in arguments, and the
# action layer executes each step under sandboxed permissions.
dictReflection = objOrchestrator.run(
    "Update NAVs for owner SG, record today's history, then give me "
    "a performance review and flag any fund down more than 8% from its peak.",
    owner_name="SG",
)

print_rich_reflection(dictReflection)
# Out:
# [Orchestrator] Context gathered: 11 holding row(s).
# [Orchestrator] Task assignment - subgoals: ['update_navs', 'record_history',
# 'performance_review', 'flag_risk']
# [Orchestrator] update_navs -> ok
# NAV history already recorded for 2026-07-27 skipping (run FetchNAVsAll for a new date first).
# [Orchestrator] record_history -> ok
# [Orchestrator] performance_review -> ok
# [Orchestrator] flag_risk -> ok
# [Orchestrator] Resource allocation - ok=4
# [Orchestrator] Reflection: Completed 4/4 step(s) successfully. 11 of 11 fund(s)
# had NAVs updated; 0 failure(s). Performance computed for 11 fund(s). 7 fund(s)
# flagged past the 8% drawdown threshold.
# --------------------------------------------------------------------------------
# Goal: Update NAVs for owner SG, record today's history, then give me a performance
# review and flag any fund down more than 8% from its peak.
# Subgoals: ['update_navs', 'record_history', 'performance_review', 'flag_risk']
# === Execution Log (4 steps) ===
#
#  1. ✅ update_navs  [OK]
#     Time : 2026-07-27T14:44:34
#     Args : {"owner_name": "SG"}
#     Result:
# {
#   "updated": 11,
#   "total": 11,
#   "failures": [],
#   "rejected": []
# }
#  2. ✅ record_history  [OK]
#     Time : 2026-07-27T14:44:34
#     Args : {"owner_name": "SG"}
#     Result:
# {
#   "recorded": true
# }
#  3. ✅ performance_review  [OK]
#     Time : 2026-07-27T14:44:34
#     Args : {"owner_name": "SG"}
#     Result:
# {
#   "funds": [
#     {
#       "fund_name": "ADITYA BIRLA SUN LIFE SILVER ETF FOF REGULAR-GROWTH",
#       "owner_name": "SG",
#       "cagr": -0.1297452688001972,
#       "drawdown": 0.4023980576657152,
#       "below_recent_average": true,
#       "alpha_vs_benchmark": null
#     },
#     {
#       "fund_name": "HDFC SILVER ETF FOF REGULAR-GROWTH",
#       "owner_name": "SG",
#       "cagr": -0.14165224528196552,
#       "drawdown": 0.4082756256088776,
#       "below_recent_average": true,
#       "alpha_vs_benchmark": null
#     },
#     {
#       "fund_name": "HSBC INFRASTRUCTURE FUND-REGULAR GROWTH",
#       "owner_name": "SG",
#       "cagr": 0.3525716210955283,
#       "drawdown": 0.07368372589116834,
#       "below_recent_average": true,
#       "alpha_vs_benchmark": null
#     },
#     {
#       "fund_name": "ICICI PRUDENTIAL LARGE & MID CAP FUND-GROWTH",
#       "owner_name": "SG",
#       "cagr": 0.256501464698385,
#       "drawdown": 0.039431242182871286,
#       "below_recent_average": false,
#       "alpha_vs_benchmark": null
#     },
#     {
#       "fund_name": "ICICI PRUDENTIAL SILVER ETF FOF-GROWTH",
#       "owner_name": "SG",
#       "cagr": -0.13353416441901111,
#       "drawdown": 0.4020465986996889,
#       "below_recent_average": true,
#       "alpha_vs_benchmark": null
#     },
#     {
#       "fund_name": "LIC MF CONSUMPTION FUND REGULAR-GROWTH",
#       "owner_name": "SG",
#       "cagr": 0.3436842587292055,
#       "drawdown": 0.0413106834877036,
#       "below_recent_average": false,
#       "alpha_vs_benchmark": null
#     },
#     {
#       "fund_name": "NIPPON INDIA LARGE CAP FUND-GROWTH",
#       "owner_name": "SG",
#       "cagr": 0.1589109610632704,
#       "drawdown": 0.06812412026260754,
#       "below_recent_average": true,
#       "alpha_vs_benchmark": null
#     },
#     {
#       "fund_name": "NIPPON INDIA SILVER ETF FOF REGULAR-GROWTH",
#       "owner_name": "SG",
#       "cagr": -0.13359435669875275,
#       "drawdown": 0.40508342524835056,
#       "below_recent_average": true,
#       "alpha_vs_benchmark": null
#     },
#     {
#       "fund_name": "SBI GOLD FUND-GROWTH",
#       "owner_name": "SG",
#       "cagr": -0.10368873444038884,
#       "drawdown": 0.19583928633655084,
#       "below_recent_average": true,
#       "alpha_vs_benchmark": null
#     },
#     {
#       "fund_name": "SBI SILVER ETF FOF REGULAR-GROWTH",
#       "owner_name": "SG",
#       "cagr": -0.1341789879184242,
#       "drawdown": 0.39611203743198015,
#       "below_recent_average": true,
#       "alpha_vs_benchmark": null
#     },
#     {
#       "fund_name": "TATA SILVER ETF FOF REGULAR-GROWTH",
#       "owner_name": "SG",
#       "cagr": -0.13930761267333713,
#       "drawdown": 0.3834174530184905,
#       "below_recent_average": true,
#       "alpha_vs_benchmark": null
#     }
#   ]
# }
#  4. ✅ flag_risk  [OK]
#     Time : 2026-07-27T14:44:34
#     Args : {"owner_name": "SG", "threshold": 0.08}
#     Result:
# {
#   "threshold": 0.08,
#   "flagged": [
#     {
#       "fund_name": "ADITYA BIRLA SUN LIFE SILVER ETF FOF REGULAR-GROWTH",
#       "owner_name": "SG",
#       "drawdown": 0.4023980576657152
#     },
#     {
#       "fund_name": "HDFC SILVER ETF FOF REGULAR-GROWTH",
#       "owner_name": "SG",
#       "drawdown": 0.4082756256088776
#     },
#     {
#       "fund_name": "ICICI PRUDENTIAL SILVER ETF FOF-GROWTH",
#       "owner_name": "SG",
#       "drawdown": 0.4020465986996889
#     },
#     {
#       "fund_name": "NIPPON INDIA SILVER ETF FOF REGULAR-GROWTH",
#       "owner_name": "SG",
#       "drawdown": 0.40508342524835056
#     },
#     {
#       "fund_name": "SBI GOLD FUND-GROWTH",
#       "owner_name": "SG",
#       "drawdown": 0.19583928633655084
#     },
#     {
#       "fund_name": "SBI SILVER ETF FOF REGULAR-GROWTH",
#       "owner_name": "SG",
#       "drawdown": 0.39611203743198015
#     },
#     {
#       "fund_name": "TATA SILVER ETF FOF REGULAR-GROWTH",
#       "owner_name": "SG",
#       "drawdown": 0.3834174530184905
#     }
#   ]
# }
#
# ________________________________________________________________________________
# ╭───────────────────────────────── 🤖 Agent Reflection — ✅ SUCCESS (4/4 steps) ──────────────────────────────────╮
# │ Completed 4/4 step(s) successfully. 11 of 11 fund(s) had NAVs updated; 0 failure(s). Performance computed for   │
# │ 11 fund(s). 7 fund(s) flagged past the 8% drawdown threshold.                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# # Example 2

# %% [markdown]
# ## Fund 1

# %%
dictReflection = objOrchestrator.run(
    'Give me a portfolio report and plot the NAV history for '
    '"NIPPON INDIA SILVER ETF FOF REGULAR-GROWTH".',
    owner_name="SG",
)

print_rich_reflection(dictReflection)
# Out:
# [Orchestrator] Context gathered: 11 holding row(s).
# [Orchestrator] Task assignment - subgoals: ['record_history',
# 'portfolio_report', 'plot_fund']
# NAV history already recorded for 2026-07-27 skipping (run FetchNAVsAll for a new date first).
# [Orchestrator] record_history -> ok
# [Orchestrator] portfolio_report -> ok
# [Orchestrator] plot_fund -> ok
# [Orchestrator] Resource allocation - ok=3
# [Orchestrator] Reflection: Completed 3/3 step(s) successfully. Total cost value
# ₹1,100,000.00, total expected value ₹1,101,566.36, P&L ₹1,566.36.
# --------------------------------------------------------------------------------
# Goal: Give me a portfolio report and plot the NAV history for "NIPPON INDIA SILVER ETF
# FOF REGULAR-GROWTH".
# Subgoals: ['record_history', 'portfolio_report', 'plot_fund']
# === Execution Log (3 steps) ===
#
#  1. ✅ record_history  [OK]
#     Time : 2026-07-27T14:46:13
#     Args : {"owner_name": "SG"}
#     Result:
# {
#   "recorded": true
# }
#  2. ✅ portfolio_report  [OK]
#     Time : 2026-07-27T14:46:13
#     Args : {"owner_name": "SG"}
#     Result:
#     Portfolio Summary:
#     --------------------------------------------------------------------------------------------------------------
#     Fund Name                                               Owner    Cost Value  Expected Value          P&L
#     --------------------------------------------------------------------------------------------------------------
#     ADITYA BIRLA SUN LIFE SILVER ETF FOF REGULAR-GROWTH     SG        100000.00        95861.87     -4138.13
#     HDFC SILVER ETF FOF REGULAR-GROWTH                      SG        100000.00        95461.08     -4538.92
#     HSBC INFRASTRUCTURE FUND-REGULAR GROWTH                 SG        100000.00       109619.32     +9619.32
#     ICICI PRUDENTIAL LARGE & MID CAP FUND-GROWTH            SG        100000.00       107190.53     +7190.53
#     ICICI PRUDENTIAL SILVER ETF FOF-GROWTH                  SG        100000.00        95734.75     -4265.25
#     LIC MF CONSUMPTION FUND REGULAR-GROWTH                  SG        100000.00       109399.77     +9399.77
#     NIPPON INDIA LARGE CAP FUND-GROWTH                      SG        100000.00       104587.13     +4587.13
#     NIPPON INDIA SILVER ETF FOF REGULAR-GROWTH              SG        100000.00        95732.73     -4267.27
#     SBI GOLD FUND-GROWTH                                    SG        100000.00        96725.79     -3274.21
#     SBI SILVER ETF FOF REGULAR-GROWTH                       SG        100000.00        95713.08     -4286.92
#     TATA SILVER ETF FOF REGULAR-GROWTH                      SG        100000.00        95540.31     -4459.69
#     --------------------------------------------------------------------------------------------------------------
#     TOTAL                                                            1100000.00      1101566.36     +1566.36
#     --------------------------------------------------------------------------------------------------------------
#  3. ✅ plot_fund  [OK]
#     Time : 2026-07-27T14:46:13
#     Args : {"owner_name": "SG", "fund_name": "NIPPON INDIA SILVER ETF FOF REGULAR-GROWTH"}
#     Result:
# {
#   "fund_name": "NIPPON INDIA SILVER ETF FOF REGULAR-GROWTH",
#   "saved_to": null
# }
#
# ________________________________________________________________________________
# ╭───────────────────────────────── 🤖 Agent Reflection — ✅ SUCCESS (3/3 steps) ──────────────────────────────────╮
# │ Completed 3/3 step(s) successfully. Total cost value ₹1,100,000.00, total expected value ₹1,101,566.36, P&L     │
# │ ₹1,566.36.                                                                                                      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## Fund 2

# %%
dictReflection = objOrchestrator.run(
    'Give me a portfolio report and plot the NAV history for '
    '"ICICI PRUDENTIAL LARGE & MID CAP FUND-GROWTH".',
    owner_name="SG",
)

print_rich_reflection(dictReflection)
# Out:
# [Orchestrator] Context gathered: 11 holding row(s).
# [Orchestrator] Task assignment - subgoals: ['update_navs', 'record_history',
# 'plot_fund']
# [Orchestrator] update_navs -> ok
# NAV history already recorded for 2026-07-27 skipping (run FetchNAVsAll for a new date first).
# [Orchestrator] record_history -> ok
# [Orchestrator] plot_fund -> ok
# [Orchestrator] Resource allocation - ok=3
# [Orchestrator] Reflection: Completed 3/3 step(s) successfully. 11 of 11 fund(s)
# had NAVs updated; 0 failure(s).
# --------------------------------------------------------------------------------
# Goal: Give me a portfolio report and plot the NAV history for "ICICI PRUDENTIAL LARGE
# & MID CAP FUND-GROWTH".
# Subgoals: ['update_navs', 'record_history', 'plot_fund']
# === Execution Log (3 steps) ===
#
#  1. ✅ update_navs  [OK]
#     Time : 2026-07-27T14:47:01
#     Args : {"owner_name": "SG"}
#     Result:
# {
#   "updated": 11,
#   "total": 11,
#   "failures": [],
#   "rejected": []
# }
#  2. ✅ record_history  [OK]
#     Time : 2026-07-27T14:47:01
#     Args : {"owner_name": "SG"}
#     Result:
# {
#   "recorded": true
# }
#  3. ✅ plot_fund  [OK]
#     Time : 2026-07-27T14:47:02
#     Args : {"owner_name": "SG", "fund_name": "ICICI PRUDENTIAL LARGE & MID CAP FUND-GROWTH"}
#     Result:
# {
#   "fund_name": "ICICI PRUDENTIAL LARGE & MID CAP FUND-GROWTH",
#   "saved_to": null
# }
#
# ________________________________________________________________________________
# ╭──────────────────── 🤖 Agent Reflection — ✅ SUCCESS (3/3 steps) ────────────────────╮
# │ Completed 3/3 step(s) successfully. 11 of 11 fund(s) had NAVs updated; 0 failure(s). │
# ╰──────────────────────────────────────────────────────────────────────────────────────╯
